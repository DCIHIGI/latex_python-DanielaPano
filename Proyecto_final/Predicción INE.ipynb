# %%
##Importar librerías a utilizar
import numpy as np 
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import os
import glob
import pandas as pd
import re
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
import glob
files=glob.glob("./data//**.txt")

# %%
files
# Out:
# ['./data\\201909.txt',
#  './data\\201910.txt',
#  './data\\201911.txt',
#  './data\\201912.txt',
#  './data\\202001.txt',
#  './data\\202002.txt',
#  './data\\202003.txt',
#  './data\\202004.txt',
#  './data\\202005.txt',
#  './data\\202006.txt',
#  './data\\202007.txt',
#  './data\\202008.txt',
#  './data\\202009.txt',
#  './data\\202010.txt',
#  './data\\202011.txt',
#  './data\\202012.txt']

# %%
data1=pd.read_csv(files[0],usecols=[0,1,2,3,9])

# %%
data1_GTO=data1[data1['ENTIDAD']==11]

# %%
data2=pd.read_csv(files[1],usecols=[0,1,2,3,9])

# %%
data2_GTO=data2[data2['ENTIDAD']==11]

# %%
data3=pd.read_csv(files[2],usecols=[0,1,2,3,9])
data3_GTO=data3[data3['ENTIDAD']==11]

# %%
data4=pd.read_csv(files[3],usecols=[0,1,2,3,9])
data4_GTO=data4[data4['ENTIDAD']==11]

# %%
data5=pd.read_csv(files[4],usecols=[0,1,2,3,13])
data5_GTO=data5[data5['ENTIDAD']==11]

# %%
data6=pd.read_csv(files[5],usecols=[0,1,2,3,13])
data6_GTO=data6[data6['ENTIDAD']==11]

# %%
data7=pd.read_csv(files[6],usecols=[0,1,2,3,13])
data7_GTO=data7[data7['ENTIDAD']==11]

# %%
data8=pd.read_csv(files[7],usecols=[0,1,2,3,13])
data8_GTO=data8[data8['ENTIDAD']==11]

# %%
data9=pd.read_csv(files[8],usecols=[0,1,2,3,13])
data9_GTO=data9[data9['ENTIDAD']==11]

# %%
data10=pd.read_csv(files[9],usecols=[0,1,2,3,13])
data10_GTO=data10[data10['ENTIDAD']==11]

# %%
data11=pd.read_csv(files[10],usecols=[0,1,2,3,13])
data11_GTO=data11[data11['ENTIDAD']==11]

# %%
data12=pd.read_csv(files[11],usecols=[0,1,2,3,13])
data12_GTO=data12[data12['ENTIDAD']==11]

# %%
data13=pd.read_csv(files[12],usecols=[0,1,2,3,13])
data13_GTO=data13[data13['ENTIDAD']==11]

# %%
data14=pd.read_csv(files[13],usecols=[0,1,2,3,13])
data14_GTO=data14[data14['ENTIDAD']==11]

# %%
data15=pd.read_csv(files[14],usecols=[0,1,2,3,13])
data15_GTO=data15[data15['ENTIDAD']==11]

# %%
data16=pd.read_csv(files[15],usecols=[0,1,2,3,13])
data16_GTO=data16[data16['ENTIDAD']==11]

# %%
LISTA_NAL_MPO=data1_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO
# Out:
#            ENTIDAD  DISTRITO  SECCION    LISTA
# MUNICIPIO
# 1              550       650     1275    67427
# 2              990      1260     8595    94040
# 3             1133       206    19776   128446
# 4              484       616    11682    49656
# 5              473       602    13287    67868
# 6               55         5     1665     4207
# 7             2728      2656   162381   378361
# 8              462       294    24675    31431
# 9              473        86    27090    60267
# 10             110       140     6565     9283
# 11             605       550    37895    74256
# 12             242       286    16009    23212
# 13             132        12     8946    18343
# 14             781        71    55877   113311
# 15            1023       372    80817   139096
# 16             143       169    11986    16845
# 17            2739      3315   262197   422390
# 18             286       338    30953    28858
# 19             616       784    68971    40842
# ...

# %%
LISTA_NAL_MPO2=data2_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO2
# Out:
#            ENTIDAD  DISTRITO  SECCION    LISTA
# MUNICIPIO
# 1              550       650     1275    67541
# 2              990      1260     8595    94139
# 3             1133       206    19776   128937
# 4              484       616    11682    49787
# 5              473       602    13287    68120
# 6               55         5     1665     4228
# 7             2728      2656   162381   379387
# 8              462       294    24675    31546
# 9              473        86    27090    60366
# 10             110       140     6565     9315
# 11             605       550    37895    74574
# 12             242       286    16009    23288
# 13             132        12     8946    18396
# 14             781        71    55877   113789
# 15            1023       372    80817   139676
# 16             143       169    11986    16890
# 17            2739      3315   262197   423691
# 18             286       338    30953    28921
# 19             616       784    68971    40902
# ...

# %%
LISTA_NAL_MPO3=data3_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO3
# Out:
#            ENTIDAD  DISTRITO  SECCION    LISTA
# MUNICIPIO
# 1              550       650     1275    67450
# 2              990      1260     8595    93825
# 3             1133       206    19776   128731
# 4              484       616    11682    49699
# 5              473       602    13287    67992
# 6               55         5     1665     4203
# 7             2728      2656   162381   378139
# 8              462       294    24675    31501
# 9              473        86    27090    60337
# 10             110       140     6565     9288
# 11             605       550    37895    74297
# 12             242       286    16009    23300
# 13             132        12     8946    18303
# 14             781        71    55877   113675
# 15            1023       372    80817   139382
# 16             143       169    11986    16862
# 17            2739      3315   262197   422665
# 18             286       338    30953    28920
# 19             616       784    68971    40795
# ...

# %%
LISTA_NAL_MPO4=data4_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO4
# Out:
#            ENTIDAD  DISTRITO  SECCION    LISTA
# MUNICIPIO
# 1              550       650     1275    67463
# 2              990      1260     8595    93970
# 3             1133       206    19776   128978
# 4              484       616    11682    49818
# 5              473       602    13287    68218
# 6               55         5     1665     4200
# 7             2728      2656   162381   378402
# 8              462       294    24675    31455
# 9              473        86    27090    60325
# 10             110       140     6565     9318
# 11             605       550    37895    74359
# 12             242       286    16009    23340
# 13             132        12     8946    18361
# 14             781        71    55877   113874
# 15            1023       372    80817   139590
# 16             143       169    11986    16872
# 17            2739      3315   262197   423258
# 18             286       338    30953    28947
# 19             616       784    68971    40873
# ...

# %%
LISTA_NAL_MPO5=data5_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO5
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NACIONAL
# MUNICIPIO
# 1              550       650     1275           65505
# 2              990      1260     8595           91712
# 3             1133       206    19776          125884
# 4              484       616    11682           48907
# 5              473       602    13287           66789
# 6               55         5     1665            4145
# 7             2728      2656   162381          370594
# 8              462       294    24675           30822
# 9              473        86    27090           58753
# 10             110       140     6565            9192
# 11             605       550    37895           72878
# 12             242       286    16009           22885
# 13             132        12     8946           17908
# 14             781        71    55877          111422
# 15            1023       372    80817          136661
# 16             143       169    11986           16529
# ...

# %%
LISTA_NAL_MPO6=data6_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO6
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      66245
# 2              990      1260     8595      92759
# 3             1133       206    19776     127461
# 4              484       616    11682      49311
# 5              473       602    13287      67553
# 6               55         5     1665       4162
# 7             2728      2656   162381     374915
# 8              462       294    24675      31080
# 9              473        86    27090      59504
# 10             110       140     6565       9256
# 11             605       550    37895      73771
# 12             242       286    16009      23136
# 13             132        12     8946      18099
# 14             781        71    55877     112807
# 15            1023       372    80817     138191
# 16             143       169    11986      16637
# 17            2739      3315   262197     419331
# 18             286       338    30953      28785
# ...

# %%
LISTA_NAL_MPO7=data7_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO7
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      66750
# 2              990      1260     8595      93343
# 3             1133       206    19776     128544
# 4              484       616    11682      49596
# 5              473       602    13287      68063
# 6               55         5     1665       4212
# 7             2728      2656   162381     378228
# 8              462       294    24675      31406
# 9              473        86    27090      59917
# 10             110       140     6565       9279
# 11             605       550    37895      74222
# 12             242       286    16009      23249
# 13             132        12     8946      18266
# 14             781        71    55877     113601
# 15            1023       372    80817     139170
# 16             143       169    11986      16690
# 17            2739      3315   262197     423570
# 18             286       338    30953      28935
# ...

# %%
LISTA_NAL_MPO8=data8_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO8
# Out:
#            ENTIDAD  DISTRITO    SECCION  LISTA_NAL
# MUNICIPIO
# 1.0          550.0     650.0     1275.0    66736.0
# 2.0          990.0    1260.0     8595.0    93340.0
# 3.0         1133.0     206.0    19776.0   128543.0
# 4.0          484.0     616.0    11682.0    49596.0
# 5.0          473.0     602.0    13287.0    68058.0
# 6.0           55.0       5.0     1665.0     4212.0
# 7.0         2728.0    2656.0   162381.0   378153.0
# 8.0          462.0     294.0    24675.0    31385.0
# 9.0          473.0      86.0    27090.0    59910.0
# 10.0         110.0     140.0     6565.0     9278.0
# 11.0         605.0     550.0    37895.0    74218.0
# 12.0         242.0     286.0    16009.0    23242.0
# 13.0         132.0      12.0     8946.0    18266.0
# 14.0         781.0      71.0    55877.0   113598.0
# 15.0        1023.0     372.0    80817.0   139169.0
# 16.0         143.0     169.0    11986.0    16689.0
# 17.0        2739.0    3315.0   262197.0   423403.0
# ...

# %%
LISTA_NAL_MPO9=data9_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO9
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68057
# 2              990      1260     8595      94967
# 3             1133       206    19776     130720
# 4              484       616    11682      50283
# 5              473       602    13287      69125
# 6               55         5     1665       4244
# 7             2728      2656   162381     383007
# 8              462       294    24675      31800
# 9              473        86    27090      60931
# 10             110       140     6565       9376
# 11             605       550    37895      75392
# 12             242       286    16009      23598
# 13             132        12     8946      18553
# 14             781        71    55877     115367
# 15            1023       372    80817     141334
# 16             143       169    11986      16919
# 17            2739      3315   262197     428437
# 18             286       338    30953      29248
# ...

# %%
LISTA_NAL_MPO10=data10_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO10
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68054
# 2              990      1260     8595      94967
# 3             1133       206    19776     130717
# 4              484       616    11682      50281
# 5              473       602    13287      69124
# 6               55         5     1665       4244
# 7             2728      2656   162381     383002
# 8              462       294    24675      31799
# 9              473        86    27090      60931
# 10             110       140     6565       9376
# 11             605       550    37895      75392
# 12             242       286    16009      23596
# 13             132        12     8946      18553
# 14             781        71    55877     115367
# 15            1023       372    80817     141332
# 16             143       169    11986      16918
# 17            2739      3315   262197     428428
# 18             286       338    30953      29247
# ...

# %%
LISTA_NAL_MPO11=data11_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO11
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68052
# 2              990      1260     8595      94952
# 3             1133       206    19776     130708
# 4              484       616    11682      50273
# 5              473       602    13287      69114
# 6               55         5     1665       4244
# 7             2728      2656   162381     382980
# 8              462       294    24675      31797
# 9              473        86    27090      60929
# 10             110       140     6565       9374
# 11             605       550    37895      75390
# 12             242       286    16009      23592
# 13             132        12     8946      18546
# 14             781        71    55877     115364
# 15            1023       372    80817     141323
# 16             143       169    11986      16917
# 17            2739      3315   262197     428395
# 18             286       338    30953      29247
# ...

# %%
LISTA_NAL_MPO12=data12_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO12
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68093
# 2              990      1260     8595      95009
# 3             1133       206    19776     130992
# 4              484       616    11682      50287
# 5              473       602    13287      69132
# 6               55         5     1665       4249
# 7             2728      2656   162381     383071
# 8              462       294    24675      31818
# 9              473        86    27090      60987
# 10             110       140     6565       9373
# 11             605       550    37895      75242
# 12             242       286    16009      23580
# 13             132        12     8946      18578
# 14             781        71    55877     115442
# 15            1023       372    80817     141551
# 16             143       169    11986      16915
# 17            2739      3315   262197     428883
# 18             286       338    30953      29245
# ...

# %%
LISTA_NAL_MPO13=data13_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO13
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68244
# 2              990      1260     8595      95209
# 3             1133       206    19776     131172
# 4              484       616    11682      50324
# 5              473       602    13287      69287
# 6               55         5     1665       4253
# 7             2728      2656   162381     383484
# 8              462       294    24675      31816
# 9              473        86    27090      61077
# 10             110       140     6565       9372
# 11             605       550    37895      75291
# 12             242       286    16009      23595
# 13             132        12     8946      18589
# 14             781        71    55877     115195
# 15            1023       372    80817     141321
# 16             143       169    11986      16931
# 17            2739      3315   262197     429869
# 18             286       338    30953      29243
# ...

# %%
LISTA_NAL_MPO14=data14_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO14
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68241
# 2              990      1260     8595      95595
# 3             1133       206    19776     131903
# 4              484       616    11682      50647
# 5              473       602    13287      69745
# 6               55         5     1665       4245
# 7             2728      2656   162381     385535
# 8              462       294    24675      32043
# 9              473        86    27090      61486
# 10             110       140     6565       9380
# 11             605       550    37895      75457
# 12             242       286    16009      23675
# 13             132        12     8946      18656
# 14             781        71    55877     115921
# 15            1023       372    80817     142448
# 16             143       169    11986      16941
# 17            2739      3315   262197     431795
# 18             286       338    30953      29493
# ...

# %%
LISTA_NAL_MPO15=data15_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO15
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68422
# 2              990      1260     8595      96005
# 3             1133       206    19776     132669
# 4              484       616    11682      50867
# 5              473       602    13287      70072
# 6               55         5     1665       4262
# 7             2728      2656   162381     386714
# 8              462       294    24675      32435
# 9              473        86    27090      61679
# 10             110       140     6565       9413
# 11             605       550    37895      75724
# 12             231       273    15279      23745
# 13             132        12     8946      18746
# 14             781        71    55877     115973
# 15            1023       372    80817     142986
# 16             143       169    11986      16993
# 17            2739      3315   262197     434445
# 18             286       338    30953      29758
# ...

# %%
LISTA_NAL_MPO16=data16_GTO[1:].groupby(['MUNICIPIO']).sum()
LISTA_NAL_MPO16
# Out:
#            ENTIDAD  DISTRITO  SECCION  LISTA_NAL
# MUNICIPIO
# 1              550       650     1275      68611
# 2              990      1260     8595      95934
# 3             1133       206    19776     133489
# 4              484       616    11682      50877
# 5              473       602    13287      70194
# 6               55         5     1665       4261
# 7             2728      2656   162381     387848
# 8              462       294    24675      32565
# 9              473        86    27090      61915
# 10             110       140     6565       9456
# 11             605       550    37895      75755
# 12             231       273    15279      23791
# 13             132        12     8946      18829
# 14             781        71    55877     116762
# 15            1122       408   111674     143820
# 16             143       169    11986      16946
# 17            2739      3315   262197     436055
# 18             286       338    30953      29686
# ...

# %%
date=[]
date_=[]
files_=[]

for i,file in enumerate(files):
    date.append(re.findall(r'\d+',file)[0])


temp=sorted(range(len(date)), key=date.__getitem__)

for i in temp:
    date_.append(date[i])
    print(date[i],files[i])
    files_.append(files[i])
# Out:
# 201909 ./data\201909.txt
# 201910 ./data\201910.txt
# 201911 ./data\201911.txt
# 201912 ./data\201912.txt
# 202001 ./data\202001.txt
# 202002 ./data\202002.txt
# 202003 ./data\202003.txt
# 202004 ./data\202004.txt
# 202005 ./data\202005.txt
# 202006 ./data\202006.txt
# 202007 ./data\202007.txt
# 202008 ./data\202008.txt
# 202009 ./data\202009.txt
# 202010 ./data\202010.txt
# 202011 ./data\202011.txt
# 202012 ./data\202012.txt

# %%
for i,file in enumerate(files_):
    data=pd.read_csv(file)
    data=data[1:]
    data=data[data['ENTIDAD']==11][1:]
    mpo=data.groupby(['MUNICIPIO']).sum()
    if i==0 :
        if 'LISTA_NAL' in mpo.columns:
            df_mpo = pd.DataFrame(mpo['LISTA_NAL'])
        if 'LISTA_NACIONAL' in mpo.columns:
            df_mpo = pd.DataFrame(mpo['LISTA_NACIONAL'])
        if 'LISTA' in mpo.columns:
            df_mpo = pd.DataFrame(mpo['LISTA'])
    else:
        if 'LISTA_NAL' in mpo.columns:
            df_mpo[date_[i]]=mpo['LISTA_NAL']
        if 'LISTA_NACIONAL' in mpo.columns:
            df_mpo[date_[i]]=mpo['LISTA_NACIONAL']
        if 'LISTA' in mpo.columns:
            df_mpo[date_[i]]=mpo['LISTA']
# Out:
# C:\Users\DanyP\miniconda3\envs\MiEntorno\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_mpo
# Out:
#              LISTA   201910   201911   201912   202001   202002   202003  \
# MUNICIPIO
# 1            67427    67541    67450    67463    65505    66245    66750
# 2            94040    94139    93825    93970    91712    92759    93343
# 3           128446   128937   128731   128978   125884   127461   128544
# 4            49656    49787    49699    49818    48907    49311    49596
# 5            67868    68120    67992    68218    66789    67553    68063
# 6             4207     4228     4203     4200     4145     4162     4212
# 7           378361   379387   378139   378402   370594   374915   378228
# 8            31431    31546    31501    31455    30822    31080    31406
# 9            60267    60366    60337    60325    58753    59504    59917
# 10            9283     9315     9288     9318     9192     9256     9279
# 11           74256    74574    74297    74359    72878    73771    74222
# 12           23212    23288    23300    23340    22885    23136    23249
# ...

# %%
plt.figure(figsize=(20,10))

for i in range(4):
    plt.plot(df_mpo.iloc[i])
    plt.yscale('log')

# %%
##Regresión lineal para cada una
municipios=np.asarray(df_mpo)

# %%
fits=[]
prediction_lnal=[]

for i in range(len(municipios)):
    xx=np.arange(len(municipios[i]))
    ma, ba = np. polyfit(xx, municipios[i],1,w=municipios[i])
    fits.append([ma,ba])
    pred=ma*(xx[-12]+12)+ba
  
    prediction_lnal.append(pred)

# %%
df_mpo['Prediction LNAL AÑO DESPUÉS']=prediction_lnal

# %%
df_mpo
# Out:
#              LISTA   201910   201911   201912   202001   202002   202003  \
# MUNICIPIO
# 1            67427    67541    67450    67463    65505    66245    66750
# 2            94040    94139    93825    93970    91712    92759    93343
# 3           128446   128937   128731   128978   125884   127461   128544
# 4            49656    49787    49699    49818    48907    49311    49596
# 5            67868    68120    67992    68218    66789    67553    68063
# 6             4207     4228     4203     4200     4145     4162     4212
# 7           378361   379387   378139   378402   370594   374915   378228
# 8            31431    31546    31501    31455    30822    31080    31406
# 9            60267    60366    60337    60325    58753    59504    59917
# 10            9283     9315     9288     9318     9192     9256     9279
# 11           74256    74574    74297    74359    72878    73771    74222
# 12           23212    23288    23300    23340    22885    23136    23249
# ...

# %%
##obtener el número de casillas
suma13_mpos= (6.852635e+04/750)+(9.591634e+04/750)+(1.328844e+05/750)+(5.082436e+04/750)+(7.013171e+04/750)+(4.266440e+03/750)+(3.871595e+05/750)+(3.230075e+04/750)+(6.169008e+04/750)+(9.428570e+03/750)+(7.586525e+04/750)+(2.379749e+04/750)+(1.876193e+04/750)
suma26_mpos= (1.165340e+05/750)+(1.432309e+05/750)+(1.695960e+04/750)+(4.345915e+05/750)+(2.963962e+04/750)+(4.166652e+04/750)+(1.170904e+06/750)+(4.433597e+04/750)+(1.849405e+04/750)+(1.274828e+05/750)+(1.092250e+04/750)+(5.699138e+04/750)+(4.692997e+04/750)
suma39_mpos= (2.172215e+05/750)+(8.438038e+04/750)+(2.859890e+04/750)+(8.437013e+04/750)+(9.548052e+04/750)+(6.205179e+04/750)+(9.241827e+04/750)+(4.448034e+03/750)+(6.276040e+04/750)+(6.626937e+03/750)+(1.406969e+05/750)+(1.043628e+04/750)+(3.145011e+04/750)
suma46_mpos= (1.365916e+04/750)+(5.031268e+04/750)+(1.172398e+05/750)+(1.563347e+04/750)+(4.791125e+04/750)+(8.571230e+03/750)+(6.397137e+04/750)

total_casillas=suma13_mpos+suma26_mpos+suma39_mpos+suma46_mpos
print(total_casillas)
# Out:
# 6037.966788

# %%
#Agrupar por sección
for i,file in enumerate(files_):
    data=pd.read_csv(file)
    data=data[1:]
    data=data[data['ENTIDAD']==11][1:]
    seccion=data.groupby(['SECCION']).sum()
    if i==0 :
        if 'LISTA_NAL' in seccion.columns:
            df_seccion = pd.DataFrame(seccion['LISTA_NAL'])
        if 'LISTA_NACIONAL' in seccion.columns:
            df_seccion = pd.DataFrame(seccion['LISTA_NACIONAL'])
        if 'LISTA' in seccion.columns:
            df_seccion = pd.DataFrame(seccion['LISTA'])
    else:
        if 'LISTA_NAL' in seccion.columns:
            df_seccion[date_[i]]=seccion['LISTA_NAL']
        if 'LISTA_NACIONAL' in seccion.columns:
            df_seccion[date_[i]]=seccion['LISTA_NACIONAL']
        if 'LISTA' in seccion.columns:
            df_seccion[date_[i]]=seccion['LISTA']
# Out:
# C:\Users\DanyP\miniconda3\envs\MiEntorno\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (7,8,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df_seccion
# Out:
#          LISTA  201910  201911  201912  202001  202002  202003  202004  \
# SECCION
# 1         1539    1545    1539    1538    1493    1515    1527  1527.0
# 2         1998    2008    2004    2005    1939    1963    1977  1977.0
# 3         1522    1522    1525    1520    1457    1477    1493  1493.0
# 4          945     949     949     952     915     932     938   938.0
# 5         1067    1065    1065    1064    1026    1036    1047  1045.0
# ...        ...     ...     ...     ...     ...     ...     ...     ...
# 3150      1556    1560    1578    1582    1588    1601    1615  1615.0
# 3151      1336    1343    1336    1336    1329    1343    1352  1352.0
# 3152      1074    1080    1085    1086    1080    1094    1095  1095.0
# 3153      1289    1295    1294    1302    1301    1313    1328  1328.0
# 3154      2105    2126    2136    2154    2186    2218    2248  2248.0
#
#          202005  202006  202007  202008  202009  202010  202011  202012
# SECCION
# ...

# %%
#Regresion lineal por cada sección

secciones=np.asarray(df_seccion)
secciones
# Out:
# array([[1539., 1545., 1539., ..., 1561., 1565., 1571.],
#        [1998., 2008., 2004., ..., 2028., 2028., 2033.],
#        [1522., 1522., 1525., ..., 1528., 1534., 1537.],
#        ...,
#        [1074., 1080., 1085., ..., 1112., 1118., 1125.],
#        [1289., 1295., 1294., ..., 1350., 1354., 1363.],
#        [2105., 2126., 2136., ..., 2292., 2318., 2322.]])

# %%
section=np.concatenate((secciones))

# %%
#Intento de la predicción de las secciones
#fits=[]
#prediction_seccion=[]

#for i in range(len(secciones)):
    #xx=np.arange(len(secciones[i]))
    #ma, ba = np. polyfit(xx, secciones[i],1,w=secciones[i])
   #fits.append([ma,ba])
    #pred1=ma*(x[-12]+12)+ba

    #prediction_seccion.append(pred1)
